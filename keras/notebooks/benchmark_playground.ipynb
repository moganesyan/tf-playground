# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage.transform import resize

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
BASE_PATH = Path("..")
sys.path.append(str(BASE_PATH.resolve()))

# %%
from mobilenetv1.mobilenetv1 import MobileNetV1
from mobilenetv2.mobilenetv2 import MobileNetV2

# %%
tf.__version__
# Out:
# '2.5.0'

# %% [markdown]
# ## CIFAR-10 Dataset

# %%
CLASS_NAMES = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
cifar10 = tf.keras.datasets.cifar10
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# %%
print(train_images.shape, train_labels.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)

# %%
# train_images = np.expand_dims(train_images, axis = 3)
# test_images = np.expand_dims(test_images, axis = 3)

# train_images = resize(train_images, (len(train_images),224,224,1))
# test_images = resize(test_images, (len(test_images),224,224,1))

train_labels_onehot = tf.keras.utils.to_categorical(train_labels, num_classes=len(CLASS_NAMES))
test_labels_onehot = tf.keras.utils.to_categorical(test_labels, num_classes=len(CLASS_NAMES))

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
SAMPLE_SIZE = 10
samples = np.random.randint(0, len(train_images), size = SAMPLE_SIZE)

fig, axarr = plt.subplots(5, SAMPLE_SIZE//5, figsize = (10,10))
axs = axarr.ravel()

for idx, sample in enumerate(samples):
    axs[idx].imshow(train_images[sample,:,:,:])
    axs[idx].set_title(CLASS_NAMES[train_labels[sample,0]])
    
plt.tight_layout()

# %% [markdown]
# ## Train Models

# %%
# Mobilenet V1
mobilenetv1 = MobileNetV1(train_images.shape[1:], len(CLASS_NAMES), alpha=1.0)
model_mbnet1 = mobilenetv1()

# Mobilenet V2
mobilenetv2 = MobileNetV2(train_images.shape[1:], len(CLASS_NAMES), alpha=1.0)
model_mbnet2 = mobilenetv2()
# Out:
# 2021-09-22 01:25:26.225572: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_dict = {
    'MobileNetV1': model_mbnet1,
    'MobileNetV2': model_mbnet2
}

# %%
def train_loop(model, model_name, x_train, y_train):
    print("*" * 20)
    print(f'Training {model_name}')
    opt = tf.keras.optimizers.Adam(learning_rate=0.0003)
    model.compile(optimizer=opt,
              loss=['categorical_crossentropy'],
              metrics=['accuracy'])
    
    model.fit(
        x = x_train,
        y = y_train,
        validation_split=0.20,
        verbose=1,
        epochs = 10)
    
    return model

# %%
model_dict_trained = {k: train_loop(x, k, train_images, train_labels_onehot) for k, x in model_dict.items()}
# Out:
# ********************
# Training MobileNetV1
# 2021-09-22 01:25:29.621325: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
# 1250/1250 [==============================] - 294s 232ms/step - loss: 2.0557 - accuracy: 0.2338 - val_loss: 1.8111 - val_accuracy: 0.3278
# Epoch 2/10
# 1250/1250 [==============================] - 313s 250ms/step - loss: 1.7187 - accuracy: 0.3655 - val_loss: 1.5842 - val_accuracy: 0.4242
# Epoch 3/10
# 1250/1250 [==============================] - 298s 238ms/step - loss: 1.5575 - accuracy: 0.4318 - val_loss: 1.5069 - val_accuracy: 0.4513
# Epoch 4/10
# 1250/1250 [==============================] - 283s 227ms/step - loss: 1.4528 - accuracy: 0.4729 - val_loss: 1.4402 - val_accuracy: 0.4776
# Epoch 5/10
# 1250/1250 [==============================] - 284s 227ms/step - loss: 1.3579 - accuracy: 0.5109 - val_loss: 1.3804 - val_accuracy: 0.5068
# Epoch 6/10
# 1250/1250 [==============================] - 283s 226ms/step - loss: 1.2835 - accuracy: 0.5403 - val_loss: 1.3669 - val_accuracy: 0.5152
# Epoch 7/10
# 1250/1250 [==============================] - 286s 229ms/step - loss: 1.2019 - accuracy: 0.5742 - val_loss: 1.2801 - val_accuracy: 0.5437
# Epoch 8/10
# 1250/1250 [==============================] - 291s 233ms/step - loss: 1.1304 - accuracy: 0.5998 - val_loss: 1.2750 - val_accuracy: 0.5519
# Epoch 9/10
# 1250/1250 [==============================] - 244s 195ms/step - loss: 1.0603 - accuracy: 0.6232 - val_loss: 1.2234 - val_accuracy: 0.5719
# Epoch 10/10
# 1250/1250 [==============================] - 232s 186ms/step - loss: 0.9885 - accuracy: 0.6524 - val_loss: 1.1916 - val_accuracy: 0.5839
# ********************
# Training MobileNetV2
# Epoch 1/10
# 1250/1250 [==============================] - 175s 135ms/step - loss: 2.0455 - accuracy: 0.2366 - val_loss: 1.7616 - val_accuracy: 0.3415
# Epoch 2/10
# 1250/1250 [==============================] - 165s 132ms/step - loss: 1.6799 - accuracy: 0.3769 - val_loss: 1.6575 - val_accuracy: 0.3993
# Epoch 3/10
# 1250/1250 [==============================] - 166s 133ms/step - loss: 1.5128 - accuracy: 0.4478 - val_loss: 1.4407 - val_accuracy: 0.4764
# Epoch 4/10
# 1250/1250 [==============================] - 155s 124ms/step - loss: 1.3990 - accuracy: 0.4967 - val_loss: 1.4803 - val_accuracy: 0.4629
# Epoch 5/10
# 1250/1250 [==============================] - 165s 132ms/step - loss: 1.3001 - accuracy: 0.5373 - val_loss: 1.3433 - val_accuracy: 0.5208
# Epoch 6/10
# 1250/1250 [==============================] - 176s 141ms/step - loss: 1.2054 - accuracy: 0.5721 - val_loss: 1.2646 - val_accuracy: 0.5537
# Epoch 7/10
# 1250/1250 [==============================] - 175s 140ms/step - loss: 1.1171 - accuracy: 0.6094 - val_loss: 1.2544 - val_accuracy: 0.5608
# Epoch 8/10
# 1250/1250 [==============================] - 187s 150ms/step - loss: 1.0457 - accuracy: 0.6317 - val_loss: 1.1403 - val_accuracy: 0.6067
# Epoch 9/10
# 1250/1250 [==============================] - 179s 143ms/step - loss: 0.9819 - accuracy: 0.6569 - val_loss: 1.1070 - val_accuracy: 0.6140
# Epoch 10/10
# 1250/1250 [==============================] - 196s 157ms/step - loss: 0.9255 - accuracy: 0.6775 - val_loss: 1.0997 - val_accuracy: 0.6204

# %% [markdown]
# ## Evaluate Models

# %%
def evaluate_loop(model, model_name, x_test, y_test):
    print("*" * 20)
    print(f'Evaluating {model_name}')
    
    test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)

    print('Test accuracy:', test_acc)

# %%
for k, x in model_dict_trained.items():
    evaluate_loop(x, k, test_images, test_labels_onehot)
# Out:
# ********************
# Evaluating MobileNetV1
# 313/313 - 7s - loss: 1.1855 - accuracy: 0.5912
# Test accuracy: 0.5911999940872192
# ********************
# Evaluating MobileNetV2
# 313/313 - 12s - loss: 1.1373 - accuracy: 0.6108
# Test accuracy: 0.61080002784729
